# %% [markdown]
# # Keyword search
#
# ## Setup AI Search client

# %%
import os

from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from dotenv import load_dotenv

from render_table import render_product_results

load_dotenv()

search_credential = AzureKeyCredential(os.environ["AZURE_SEARCH_API_KEY"])

search_client = SearchClient(
    f"https://{os.environ['AZURE_SEARCH_SERVICE']}.search.windows.net",
    "zava-products-index",
    credential=search_credential,
)

# %% [markdown]
# ## Perform keyword search

# %%
search_query = "25 foot hose"

results = search_client.search(search_text=search_query, top=5)

render_product_results(results)
# Out:
# AzureDeveloperCliCredential.get_token_info failed: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.
# ---------------------------------------------------------------------------
# CredentialUnavailableError                Traceback (most recent call last)
# Cell In[2], line 5
#       1 search_query = "25 foot hose"
#       2
#       3 results = search_client.search(search_text=search_query, top=5)
#       4
# ----> 5 render_product_results(results)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/render_table.py:28, in render_product_results(results, title, show_reranker)
#      25 table.add_column("Categories", style="blue", width=20)
#      26 table.add_column("Price", justify="right", style="yellow", width=8)
# ---> 28 for doc in list(results):
#      29     row = [
#      30         f"{doc['@search.score']:.3f}",
#      31     ]
#      32     if show_reranker:
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/search/documents/_paging.py:54, in SearchItemPaged.__next__(self)
#      52     first_iterator = self._first_iterator_instance()
#      53     self._page_iterator = itertools.chain.from_iterable(first_iterator)
# ---> 54 return next(self._page_iterator)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/paging.py:82, in PageIterator.__next__(self)
#      80     raise StopIteration("End of paging")
#      81 try:
# ---> 82     self._response = self._get_next(self.continuation_token)
#      83 except AzureError as error:
#      84     if not error.continuation_token:
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/search/documents/_paging.py:131, in SearchPageIterator._get_next_cb(self, continuation_token)
#     129 def _get_next_cb(self, continuation_token):
#     130     if continuation_token is None:
# --> 131         return self._client.documents.search_post(
#     132             search_request=self._initial_query.request, **self._kwargs
#     133         )
#     135     _next_link, next_page_request = unpack_continuation_token(continuation_token)
#     137     return self._client.documents.search_post(
#     138         search_request=next_page_request, **self._kwargs
#     139     )
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/search/documents/_generated/operations/_documents_operations.py:935, in DocumentsOperations.search_post(self, search_request, request_options, **kwargs)
#     931 _request.url = self._client.format_url(_request.url, **path_format_arguments)
#     933 _stream = False
#     934 pipeline_response: PipelineResponse = (
# --> 935     self._client._pipeline.run(  # pylint: disable=protected-access
#     936         _request, stream=_stream, **kwargs
#     937     )
#     938 )
#     940 response = pipeline_response.http_response
#     942 if response.status_code not in [200, 206]:
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base.py:242, in Pipeline.run(self, request, **kwargs)
#     240 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     241 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 242 return first_node.send(pipeline_request)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_redirect.py:205, in RedirectPolicy.send(self, request)
#     203 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     204 while retryable:
# --> 205     response = self.next.send(request)
#     206     redirect_location = self.get_redirect_location(response)
#     207     if redirect_location and redirect_settings["allow"]:
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_retry.py:545, in RetryPolicy.send(self, request)
#     543 self._configure_timeout(request, absolute_timeout, is_response_error)
#     544 request.context["retry_count"] = len(retry_settings["history"])
# --> 545 response = self.next.send(request)
#     546 if self.is_retry(retry_settings, response):
#     547     retry_active = self.increment(retry_settings, response=response)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_authentication.py:192, in BearerTokenCredentialPolicy.send(self, request)
#     184 def send(self, request: PipelineRequest[HTTPRequestType]) -> PipelineResponse[HTTPRequestType, HTTPResponseType]:
#     185     """Authorize request with a bearer token and send it to the next policy
#     186
#     187     :param request: The pipeline request object
#    (...)    190     :rtype: ~azure.core.pipeline.PipelineResponse
#     191     """
# --> 192     self.on_request(request)
#     193     try:
#     194         response = self.next.send(request)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_authentication.py:167, in BearerTokenCredentialPolicy.on_request(self, request)
#     164 self._enforce_https(request)
#     166 if self._token is None or self._need_new_token:
# --> 167     self._request_token(*self._scopes)
#     168 bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     169 self._update_headers(request.http_request.headers, bearer_token)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_authentication.py:142, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     135 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     136     """Request a new token from the credential.
#     137
#     138     This will call the credential's appropriate method to get a token and store it in the policy.
#     139
#     140     :param str scopes: The type of access needed.
#     141     """
# --> 142     self._token = self._get_token(*scopes, **kwargs)
#     143     self._refresh_jitter = random.randint(0, MAX_REFRESH_JITTER_SECONDS)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/core/pipeline/policies/_authentication.py:132, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#     129         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#     130             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# --> 132     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#     133 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/identity/_internal/decorators.py:23, in log_get_token.<locals>.wrapper(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def wrapper(*args, **kwargs):
#      22     try:
# ---> 23         token = fn(*args, **kwargs)
#      24         _LOGGER.log(
#      25             logging.DEBUG if within_credential_chain.get() else logging.INFO,
#      26             "%s succeeded",
#      27             fn.__qualname__,
#      28         )
#      29         if _LOGGER.isEnabledFor(logging.DEBUG):
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/identity/_credentials/azd_cli.py:160, in AzureDeveloperCliCredential.get_token_info(self, options, *scopes)
#     139 @log_get_token
#     140 def get_token_info(self, *scopes: str, options: Optional[TokenRequestOptions] = None) -> AccessTokenInfo:
#     141     """Request an access token for `scopes`.
#     142
#     143     This is an alternative to `get_token` to enable certain scenarios that require additional properties
#    (...)    158       the Azure Developer CLI but didn't receive an access token.
#     159     """
# --> 160     return self._get_token_base(*scopes, options=options)
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/identity/_credentials/azd_cli.py:188, in AzureDeveloperCliCredential._get_token_base(self, options, *scopes, **kwargs)
#     186 if claims:
#     187     command_args += ["--claims", encode_base64(claims)]
# --> 188 output = _run_command(command_args, self._process_timeout)
#     190 token = parse_token(output)
#     191 if not token:
#     192     # Try to extract a meaningful error from azd consoleMessage JSON lines
#
# File ~/Downloads/rag-with-azure-ai-search-notebooks-main/.venv/lib/python3.12/site-packages/azure/identity/_credentials/azd_cli.py:311, in _run_command(command_args, timeout)
#     309 azd_path = shutil.which(EXECUTABLE_NAME)
#     310 if not azd_path:
# --> 311     raise CredentialUnavailableError(message=CLI_NOT_FOUND)
#     313 args = [azd_path] + command_args
#     314 try:
#
# CredentialUnavailableError: Azure Developer CLI could not be found. Please visit https://aka.ms/azure-dev for installation instructions and then,once installed, authenticate to your Azure account using 'azd auth login'.

# %% [markdown]
# ## Perform keyword search #2

# %%
search_query = "water plants efficiently without waste"

results = search_client.search(search_text=search_query, top=5)

render_product_results(results)
# Out:
# ┏━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┓
# ┃ Sco… ┃ Name                 ┃ Description                                    ┃ Categories      ┃ Pri… ┃ SKU     ┃
# ┡━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━┩
# │ 5.7… │ Water-Based          │ Fast-drying water-based polyurethane with low  │ PAINT &         │ $43… │ PFPU00… │
# │      │ Polyurethane         │ odor and excellent clarity for int...          │ FINISHES,       │      │         │
# │      │                      │                                                │ POLYURETHANE    │      │         │
# ├──────┼──────────────────────┼────────────────────────────────────────────────┼─────────────────┼──────┼─────────┤
# │ 5.4… │ Water-Based Wood     │ Fast-drying water-based stain with low odor    │ PAINT &         │ $27… │ PFWS00… │
# │      │ Stain                │ and easy cleanup while maintaining w...        │ FINISHES, WOOD  │      │         │
# │      │                      │                                                │ STAIN           │      │         │
# ├──────┼──────────────────────┼────────────────────────────────────────────────┼─────────────────┼──────┼─────────┤
# │ 5.1… │ Drinking Water Safe  │ Lead-free garden hose safe for drinking water  │ GARDEN &        │ $40… │ GOHOS0… │
# │      │ Hose                 │ and filling pools.                             │ OUTDOOR, HOSES  │      │         │
# ├──────┼──────────────────────┼────────────────────────────────────────────────┼─────────────────┼──────┼─────────┤
# │ 3.2… │ Compression Fittings │ Compression fittings for connecting copper     │ PLUMBING, PIPE  │ $32… │ PLPPF0… │
# │      │                      │ pipe without soldering.                        │ FITTINGS        │      │         │
# ├──────┼──────────────────────┼────────────────────────────────────────────────┼─────────────────┼──────┼─────────┤
# │ 3.2… │ Tomato Plant Food    │ Specialized fertilizer formulated for tomatoes │ GARDEN &        │ $14… │ GOFRT0… │
# │      │                      │ and other fruiting plants.                     │ OUTDOOR,        │      │         │
# │      │                      │                                                │ FERTILIZER      │      │         │
# └──────┴──────────────────────┴────────────────────────────────────────────────┴─────────────────┴──────┴─────────┘
