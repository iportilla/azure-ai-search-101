# %% [markdown]
# # Keyword search
#
# ## Setup AI Search client

# %%
import os
import sys

sys.path.insert(0, os.path.join(os.path.dirname(os.path.abspath("__file__")), ".."))

from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from dotenv import load_dotenv

from render_table import render_product_results

load_dotenv()

search_credential = AzureKeyCredential(os.environ["AZURE_SEARCH_API_KEY"])

search_client = SearchClient(
    f"https://{os.environ['AZURE_SEARCH_SERVICE']}.search.windows.net",
    "zava-products-index",
    credential=search_credential,
)

# %% [markdown]
# ## Perform keyword search

# %%
search_query = "25 foot hose"

results = search_client.search(search_text=search_query, top=5)

render_product_results(results)
# Out:
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃  Score ┃ Name                    ┃ Description                                     ┃ Categories         ┃ Price ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ 15.637 │ Soaker Hose 25-foot     │ Porous soaker hose for efficient water delivery │ GARDEN & OUTDOOR,  │ $25.… │
# │        │                         │ directly to plant roots.                        │ HOSES              │       │
# ├────────┼─────────────────────────┼─────────────────────────────────────────────────┼────────────────────┼───────┤
# │ 11.044 │ Garden Hose 50-foot     │ Heavy-duty garden hose with brass fittings and  │ GARDEN & OUTDOOR,  │ $32.… │
# │        │                         │ kink-resistant construction.                    │ HOSES              │       │
# ├────────┼─────────────────────────┼─────────────────────────────────────────────────┼────────────────────┼───────┤
# │ 11.044 │ Expandable Hose         │ Lightweight expandable hose that extends when   │ GARDEN & OUTDOOR,  │ $50.… │
# │        │ 100-foot                │ water flows and contracts when emp...           │ HOSES              │       │
# ├────────┼─────────────────────────┼─────────────────────────────────────────────────┼────────────────────┼───────┤
# │ 10.947 │ Heavy Duty Hose 75-foot │ Commercial-grade garden hose for heavy use with │ GARDEN & OUTDOOR,  │ $58.… │
# │        │                         │ reinforced construction.                        │ HOSES              │       │
# ├────────┼─────────────────────────┼─────────────────────────────────────────────────┼────────────────────┼───────┤
# │  8.438 │ Retractable Hose Hanger │ Wall-mounted hose reel that automatically       │ STORAGE &          │ $28.… │
# │        │                         │ retracts garden hoses.                          │ ORGANIZATION,      │       │
# │        │                         │                                                 │ HOOKS & HANGERS    │       │
# └────────┴─────────────────────────┴─────────────────────────────────────────────────┴────────────────────┴───────┘

# %% [markdown]
# ## Perform keyword search #2

# %%
search_query = "water plants efficiently without waste"

results = search_client.search(search_text=search_query, top=5)

render_product_results(results)
# Out:
# ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃  Score ┃ Name                    ┃ Description                                     ┃ Categories         ┃ Price ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │  7.298 │ Water-Based Wood Stain  │ Fast-drying water-based stain with low odor and │ PAINT & FINISHES,  │ $27.… │
# │        │                         │ easy cleanup while maintaining w...             │ WOOD STAIN         │       │
# ├────────┼─────────────────────────┼─────────────────────────────────────────────────┼────────────────────┼───────┤
# │  7.298 │ Water-Based             │ Fast-drying water-based polyurethane with low   │ PAINT & FINISHES,  │ $43.… │
# │        │ Polyurethane            │ odor and excellent clarity for int...           │ POLYURETHANE       │       │
# ├────────┼─────────────────────────┼─────────────────────────────────────────────────┼────────────────────┼───────┤
# │  7.298 │ Drinking Water Safe     │ Lead-free garden hose safe for drinking water   │ GARDEN & OUTDOOR,  │ $40.… │
# │        │ Hose                    │ and filling pools.                              │ HOSES              │       │
# ├────────┼─────────────────────────┼─────────────────────────────────────────────────┼────────────────────┼───────┤
# │  4.965 │ Impact Driver 18V       │ High-torque impact driver with hex chuck for    │ POWER TOOLS,       │ $100… │
# │        │                         │ driving screws and bolts efficientl...          │ IMPACT DRIVERS     │       │
# ├────────┼─────────────────────────┼─────────────────────────────────────────────────┼────────────────────┼───────┤
# │  4.965 │ PVC Pipe 4-inch x 10ft  │ Large diameter PVC pipe for building drains and │ PLUMBING, PVC PIPE │ $21.… │
# │        │                         │ main waste lines.                               │                    │       │
# └────────┴─────────────────────────┴─────────────────────────────────────────────────┴────────────────────┴───────┘
